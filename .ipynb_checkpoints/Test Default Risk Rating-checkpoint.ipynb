# %% [markdown]
# # Default Risk Rating with Machine Learning

# %% [markdown]
# ## Applied Statistics

# %% [raw]
# Supervisor:Anthony Strittmatter
# Room: 4043
# Phone  : 0170266953
# Email: anthony.strittmatter@ensae.fr

# %% [markdown]
# A financial company asks you to perform a default risk rating. They have data about historic customer  behaviour at  the  time  of  the  loan  application. Before  they  award  new  loans, they predict the default risk based on this information. You  get  access  to  detailed  data  about 250,000 loans.  The  data  contains socio-economic characteristics,  employment  information,  and  wealth  status.  Furthermore,  you  observe whether a loan of the customer defaulted in the past or not. Your task as data analyst is to predict the default risk. For this purpose, you can use classical estimation  methods  and  more  advanced unsupervised  machine  learning  methods. The ultimate goal is to develop a tool, that enables the financial company to measure default risk in an easy interpretable way.
#
#
# DATA :
#
# - Microdata from internal records of the financial company.
#
# - The data comprises information on past defaults, income, age, experience, marital status, property, employment, and residency.
#
# - Additional data about  the  business  cycle  can  be  merged  based  on  regional information.
#
#
#
# INDICATIVE BIBLIOGRAPHY
#
# G.James, T.Hastie, D.Witten, R.J.Tibshirani (2021): An Introduction to Statistical Learning: With Applications in R, 2nd edition, Springer, https://www.statlearning.com/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open(r"C:\Users\Antoine\Downloads\description.txt") as f:
    contents = f.read()
    print(contents)
# Out:
# CONTEXT
# An organization wants to predict who possible defaulters are for the consumer loans product.
# They have data about historic customer behavior based on what they have observed.
# Hence when they acquire new customers they want to predict who is riskier and who is not.
#
# CONTENT
# All values were provided at the time of the loan application.
#
# Column			Description					Type
# income			Income of the user				int
# age			Age of the user					int
# experience		Professional experience of the user in years	int
# profession		Profession					string
# married			Whether married or single			string
# house_ownership		Owned or rented or neither			string
# car_ownership		Does the person own a car			string
# risk_flag		Defaulted on a loan				string
# currentjobyears		Years of experience in the current job		int
# currenthouseyears	Number of years in the current residence	int
# city			City of residence				string
# state			State of residence				string
#
# The risk_flag indicates whether there has been a default in the past or not.

# %%
df=pd.read_csv(r"C:\Users\Antoine\Downloads\default data.csv")
df
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# 0                 no  Mechanical_engineer                 Rewa
# 1                 no   Software_Developer             Parbhani
# 2                 no     Technical_writer            Alappuzha
# 3                yes   Software_Developer          Bhubaneswar
# 4                 no        Civil_servant  Tiruchirappalli[10]
# ...              ...                  ...                  ...
# 251995            no              Surgeon              Kolkata
# 251996            no         Army_officer                 Rewa
# 251997            no      Design_Engineer      Kalyan-Dombivli
# 251998            no     Graphic_Designer          Pondicherry
# 251999            no         Statistician                Avadi
#
#                  STATE  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# 0       Madhya_Pradesh                3                 13          0
# 1          Maharashtra                9                 13          0
# 2               Kerala                4                 10          0
# 3               Odisha                2                 12          1
# 4           Tamil_Nadu                3                 14          1
# ...                ...              ...                ...        ...
# 251995     West_Bengal                6                 11          0
# 251996  Madhya_Pradesh                6                 11          0
# 251997     Maharashtra                7                 12          0
# 251998      Puducherry                0                 10          0
# 251999      Tamil_Nadu                7                 11          0
#
# [252000 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 252000 non-null  int64
#  1   Income             252000 non-null  int64
#  2   Age                252000 non-null  int64
#  3   Experience         252000 non-null  int64
#  4   Married/Single     252000 non-null  object
#  5   House_Ownership    252000 non-null  object
#  6   Car_Ownership      252000 non-null  object
#  7   Profession         252000 non-null  object
#  8   CITY               252000 non-null  object
#  9   STATE              252000 non-null  object
#  10  CURRENT_JOB_YRS    252000 non-null  int64
#  11  CURRENT_HOUSE_YRS  252000 non-null  int64
#  12  Risk_Flag          252000 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 25.0+ MB

# %%
df.describe()
# Out:
#                   Id        Income            Age     Experience  \
# count  252000.000000  2.520000e+05  252000.000000  252000.000000
# mean   126000.500000  4.997117e+06      49.954071      10.084437
# std     72746.278255  2.878311e+06      17.063855       6.002590
# min         1.000000  1.031000e+04      21.000000       0.000000
# 25%     63000.750000  2.503015e+06      35.000000       5.000000
# 50%    126000.500000  5.000694e+06      50.000000      10.000000
# 75%    189000.250000  7.477502e+06      65.000000      15.000000
# max    252000.000000  9.999938e+06      79.000000      20.000000
#
#        CURRENT_JOB_YRS  CURRENT_HOUSE_YRS      Risk_Flag
# count    252000.000000      252000.000000  252000.000000
# mean          6.333877          11.997794       0.123000
# std           3.647053           1.399037       0.328438
# min           0.000000          10.000000       0.000000
# 25%           3.000000          11.000000       0.000000
# 50%           6.000000          12.000000       0.000000
# 75%           9.000000          13.000000       0.000000
# max          14.000000          14.000000       1.000000

# %% [markdown]
# Pour analyser numériquement le jeu de données, il serait sans doute judicieux de transformer les réponses de type oui/non en variables binaires 1/0.

# %%
df.sample(10)
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 129911  129912  6448514   30           6         single          rented
# 179575  179576  4515909   22          12         single          rented
# 189        190  9899664   45           5         single          rented
# 29361    29362  6461341   24          18         single          rented
# 51471    51472  6913338   61          16         single          rented
# 234843  234844  9315037   63          10         single          rented
# 133612  133613  1596742   79          15         single    norent_noown
# 161881  161882  5694236   39           2        married          rented
# 102003  102004   389819   29           3        married          rented
# 182852  182853  8189154   62          13         single          rented
#
#        Car_Ownership          Profession                CITY           STATE  \
# 129911            no          Magistrate        Bihar_Sharif           Bihar
# 179575           yes                Chef             Sonipat         Haryana
# 189               no  Software_Developer         Bidhannagar     West_Bengal
# 29361             no         Firefighter             Mehsana         Gujarat
# 51471            yes          Consultant              Satara     Maharashtra
# 234843            no  Petroleum_Engineer  Thiruvananthapuram          Kerala
# 133612            no  Software_Developer           Buxar[37]           Bihar
# 161881           yes           Economist     Anantapuram[24]  Andhra_Pradesh
# 102003            no             Drafter              Rampur   Uttar_Pradesh
# 182852           yes        Army_officer               Bally     West_Bengal
#
#         CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# 129911                6                 10          0
# 179575                7                 13          0
# 189                   5                 10          0
# 29361                 9                 11          0
# 51471                11                 14          1
# 234843                5                 13          0
# 133612               14                 14          0
# 161881                2                 10          0
# 102003                3                 14          0
# 182852               12                 12          0

# %% [markdown]
# ### Analysis of each variable separately

# %%
df["Married/Single"].value_counts()
# 89.8% single people (or 10.2% of married people)
# Out:
# single     226272
# married     25728
# Name: Married/Single, dtype: int64

# %%
df["House_Ownership"].value_counts()
# 92% of clients are tenants (ie rent their house)
# 5.1% of clients are homeowners
# 2.9% are neither tenants nor owners
# Out:
# rented          231898
# owned            12918
# norent_noown      7184
# Name: House_Ownership, dtype: int64

# %%
df["Car_Ownership"].value_counts()
#69.8% of people in the dataset do not own a car (30.1% of car owners)
# Out:
# no     176000
# yes     76000
# Name: Car_Ownership, dtype: int64

# %%
df["Age"].value_counts()
#each age represents between 1.3% and 2.1% of the sample studied
# Out:
# 27    5197
# 66    5092
# 48    4967
# 33    4921
# 41    4827
# 45    4806
# 54    4785
# 68    4772
# 35    4643
# 50    4624
# 69    4617
# 76    4585
# 55    4563
# 25    4543
# 72    4533
# 79    4505
# 60    4504
# 59    4498
# 53    4490
# 47    4483
# 30    4468
# 78    4455
# 22    4430
# 34    4414
# 57    4394
# 58    4368
# 56    4344
# 24    4326
# 23    4322
# 62    4311
# 31    4257
# 70    4251
# 61    4235
# 40    4233
# 43    4206
# 21    4205
# 49    4203
# 26    4156
# 37    4153
# 71    4150
# 42    4134
# 64    4132
# 29    4109
# 67    3995
# 65    3969
# 74    3954
# 63    3942
# 77    3916
# 28    3901
# 32    3834
# 75    3829
# 39    3800
# 38    3793
# 46    3627
# 44    3622
# 73    3569
# 36    3444
# 51    3397
# 52    3197
# Name: Age, dtype: int64

# %%
df["Profession"].value_counts()
#df["Profession"].nunique()
# 51 different occupations in the survey data
# Relatively "well distributed": between 1.61% and 2.36% for each profession
# Out:
# Physician                     5957
# Statistician                  5806
# Web_designer                  5397
# Psychologist                  5390
# Computer_hardware_engineer    5372
# Drafter                       5359
# Magistrate                    5357
# Fashion_Designer              5304
# Air_traffic_controller        5281
# Comedian                      5259
# Industrial_Engineer           5250
# Mechanical_engineer           5217
# Chemical_engineer             5205
# Technical_writer              5195
# Hotel_Manager                 5178
# Financial_Analyst             5167
# Graphic_Designer              5166
# Flight_attendant              5128
# Biomedical_Engineer           5127
# Secretary                     5061
# Software_Developer            5053
# Petroleum_Engineer            5041
# Police_officer                5035
# Computer_operator             4990
# Politician                    4944
# Microbiologist                4881
# Technician                    4864
# Artist                        4861
# Lawyer                        4818
# Consultant                    4808
# Dentist                       4782
# Scientist                     4781
# Surgeon                       4772
# Aviator                       4758
# Technology_specialist         4737
# Design_Engineer               4729
# Surveyor                      4714
# Geologist                     4672
# Analyst                       4668
# Army_officer                  4661
# Architect                     4657
# Chef                          4635
# Librarian                     4628
# Civil_engineer                4616
# Designer                      4598
# Economist                     4573
# Firefighter                   4507
# Chartered_Accountant          4493
# Civil_servant                 4413
# Official                      4087
# Engineer                      4048
# Name: Profession, dtype: int64

# %%
df["CITY"].value_counts()
# 317 different cities (in India)
# Out:
# Vijayanagaram       1259
# Bhopal              1208
# Bulandshahr         1185
# Saharsa[29]         1180
# Vijayawada          1172
#                     ...
# Ujjain               486
# Warangal[11][12]     459
# Bettiah[33]          457
# Katni                448
# Karaikudi            431
# Name: CITY, Length: 317, dtype: int64

# %%
df["STATE"].value_counts()
#df["STATE"].nunique()
# 29 different states in the dataset (corresponding to the total number of states in India)
# Less well "distributed": between 0.24% and 11.3%.
# but relatively consistent with the population of each Indian state
# Out:
# Uttar_Pradesh        28400
# Maharashtra          25562
# Andhra_Pradesh       25297
# West_Bengal          23483
# Bihar                19780
# Tamil_Nadu           16537
# Madhya_Pradesh       14122
# Karnataka            11855
# Gujarat              11408
# Rajasthan             9174
# Jharkhand             8965
# Haryana               7890
# Telangana             7524
# Assam                 7062
# Kerala                5805
# Delhi                 5490
# Punjab                4720
# Odisha                4658
# Chhattisgarh          3834
# Uttarakhand           1874
# Jammu_and_Kashmir     1780
# Puducherry            1433
# Mizoram                849
# Manipur                849
# Himachal_Pradesh       833
# Tripura                809
# Uttar_Pradesh[5]       743
# Chandigarh             656
# Sikkim                 608
# Name: STATE, dtype: int64

# %%
df["Risk_Flag"].value_counts()
# Of the 252,000 clients in the data, 30996 have a risk flag (12.3% of the sample)
# Out:
# 0    221004
# 1     30996
# Name: Risk_Flag, dtype: int64

# %% [markdown]
# ### Transformation of "binary" variables

# %%
# We will create Boolean variables to replace the strings.
df.replace({'Married/Single': {'married': True, 'single': False}},inplace=True)
df.replace({'Car_Ownership': {'yes': True, 'no': False}},inplace=True)
df.replace({'House_Ownership': {'rented': -1, 'owned': 1, 'norent_noown': 0 }},inplace=True)

# %%
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3           False               -1
# 1            2  7574516   40          10           False               -1
# 2            3  3991815   66           4            True               -1
# 3            4  6256451   41           2           False               -1
# 4            5  5768871   47          11           False               -1
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13           False               -1
# 251996  251997  2843572   26          10           False               -1
# 251997  251998  4522448   46           7           False               -1
# 251998  251999  6507128   45           0           False               -1
# 251999  252000  9070230   70          17           False               -1
#
#         Car_Ownership           Profession                 CITY  \
# 0               False  Mechanical_engineer                 Rewa
# 1               False   Software_Developer             Parbhani
# 2               False     Technical_writer            Alappuzha
# 3                True   Software_Developer          Bhubaneswar
# 4               False        Civil_servant  Tiruchirappalli[10]
# ...               ...                  ...                  ...
# 251995          False              Surgeon              Kolkata
# 251996          False         Army_officer                 Rewa
# 251997          False      Design_Engineer      Kalyan-Dombivli
# 251998          False     Graphic_Designer          Pondicherry
# 251999          False         Statistician                Avadi
#
#                  STATE  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# 0       Madhya_Pradesh                3                 13          0
# 1          Maharashtra                9                 13          0
# 2               Kerala                4                 10          0
# 3               Odisha                2                 12          1
# 4           Tamil_Nadu                3                 14          1
# ...                ...              ...                ...        ...
# 251995     West_Bengal                6                 11          0
# 251996  Madhya_Pradesh                6                 11          0
# 251997     Maharashtra                7                 12          0
# 251998      Puducherry                0                 10          0
# 251999      Tamil_Nadu                7                 11          0
#
# [252000 rows x 13 columns]

# %%
df1=df.groupby(["Risk_Flag"]).mean()
#df2=df.groupby(["Risk_Flag"]).median()
#no great difference
df1
# Out:
#                       Id        Income        Age  Experience  Married/Single  \
# Risk_Flag
# 0          125124.526579  5.000449e+06  50.093442   10.162042        0.104487
# 1          132246.261711  4.973359e+06  48.960350    9.531101        0.085043
#
#            House_Ownership  Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YR
# 54        0.332288         6.511599          12.098015   0.137931
# 55        0.281613         6.566513          11.998904   0.127548
# 56        0.289365         6.278085          12.289595   0.118554
# 57        0.295175         6.356168          12.070778   0.120847
# 58        0.329670         6.306090          11.983974   0.105998
# 59        0.190529         6.203201          11.786794   0.131392
# 60        0.289964         6.469139          11.988455   0.118117
# 61        0.301535         6.441322          11.996222   0.132940
# 62        0.357458         6.607052          11.930179   0.107632
# 63        0.375951         6.568493          11.969051   0.129630
# 64        0.282672         5.868103          11.773959   0.090513
# 65        0.215420         6.186193          11.910557   0.129000
# 66        0.278672         6.353692          11.984093   0.144737
# 67        0.277847         6.356696          11.932666   0.101877
# 68        0.284786         6.418273          12.088642   0.094510
# 69        0.352827         6.405241          11.863331   0.107646
# 70        0.310045         6.703599          12.081393   0.113150
# 71        0.265542         5.400482          11.791084   0.110361
# 72        0.320979         6.388705          12.055592   0.125745
# 73        0.318296         6.291118          11.951247   0.116839
# 74        0.343703         6.172484          12.013151   0.108498
# 75        0.319666         6.456777          11.989031   0.103160
# 76        0.324755         6.054744          12.163359   0.145256
# 77        0.293156         7.106997          12.047753   0.117211
# 78        0.275645         6.203816          11.817957   0.121212
# 79        0.310988         6.347836          11.919423   0.113873

# %%
# Declaring the cm variable by the color palette from seaborn
cm = sns.color_palette("coolwarm", as_cmap=True)
 
# Visualizing the DataFrame with set precision
#print("\nModified Stlying DataFrame:")
df3.style.background_gradient(cmap=cm).set_precision(3)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/3281564260.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df3.style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_ab0dc_row0_col0, #T_ab0dc_row28_col2, #T_ab0dc_row29_col7, #T_ab0dc_row56_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ab0dc_row0_col1, #T_ab0dc_row10_col8, #T_ab0dc_row45_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ab0dc_row0_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ab0dc_row0_col3, #T_ab0dc_row3_col6, #T_ab0dc_row19_col7, #T_ab0dc_row21_col1, #T_ab0dc_row31_col4, #T_ab0dc_row40_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_ab0dc_row0_col4, #T_ab0dc_row2_col0, #T_ab0dc_row5_col6, #T_ab0dc_row6_col7, #T_ab0dc_row16_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ab0dc_row0_col5, #T_ab0dc_row55_col8 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_ab0dc_row0_col6, #T_ab0dc_row5_col0, #T_ab0dc_row15_col1, #T_ab0dc_row16_col5, #T_ab0dc_row16_col8, #T_ab0dc_row31_col1, #T_ab0dc_row39_col7, #T_ab0dc_row43_col5, #T_ab0dc_row54_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ab0dc_row0_col7, #T_ab0dc_row9_col5, #T_ab0dc_row45_col8, #T_ab0dc_row52_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_ab0dc_row0_col8, #T_ab0dc_row7_col7, #T_ab0dc_row13_col3, #T_ab0dc_row14_col1, #T_ab0dc_row17_col2, #T_ab0dc_row25_col2, #T_ab0dc_row31_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_ab0dc_row1_col0, #T_ab0dc_row48_col7, #T_ab0dc_row58_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ab0dc_row1_col1, #T_ab0dc_row21_col4, #T_ab0dc_row49_col5 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_ab0dc_row1_col2, #T_ab0dc_row39_col0, #T_ab0dc_row40_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ab0dc_row1_col3, #T_ab0dc_row29_col0, #T_ab0dc_row38_col0, #T_ab0dc_row43_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T
col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ab0dc_row6_col2, #T_ab0dc_row55_col5, #T_ab0dc_row57_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_ab0dc_row6_col3, #T_ab0dc_row14_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ab0dc_row6_col4, #T_ab0dc_row32_col2, #T_ab0dc_row38_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ab0dc_row6_col5, #T_ab0dc_row26_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ab0dc_row6_col6, #T_ab0dc_row28_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_ab0dc_row7_col0, #T_ab0dc_row9_col8, #T_ab0dc_row15_col8, #T_ab0dc_row56_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ab0dc_row7_col1, #T_ab0dc_row13_col1, #T_ab0dc_row23_col2, #T_ab0dc_row24_col8, #T_ab0dc_row45_col1, #T_ab0dc_row47_col3, #T_ab0dc_row49_col2, #T_ab0dc_row53_col6, #T_ab0dc_row56_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ab0dc_row7_col2, #T_ab0dc_row8_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ab0dc_row7_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ab0dc_row7_col5, #T_ab0dc_row8_col5, #T_ab0dc_row22_col6, #T_ab0dc_row23_col5, #T_ab0dc_row36_col5, #T_ab0dc_row40_col2, #T_ab0dc_row40_col8, #T_ab0dc_row51_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ab0dc_row8_col0, #T_ab0dc_row12_col5, #T_ab0dc_row21_col6, #T_ab0dc_row31_col5, #T_ab0dc_row36_col4, #T_ab0dc_row53_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_ab0dc_row8_col1, #T_ab0dc_row38_col6, #T_ab0dc_row46_col5, #T_ab0dc_row57_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ab0dc_row8_col2, #T_ab0dc_row18_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ab0dc_row8_col3, #T_ab0dc_row12_col8, #T_ab0dc_row32_col6, #T_ab0dc_row51_col5 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_ab0dc_row8_col6, #T_ab0dc_row10_col0, #T_ab0dc_row11_col3, #T_ab0dc_row12_col6, #T_ab0dc_row53_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_ab0dc_row8_col7, #T_ab0dc_row18_col5, #T_ab0dc_row19_col3, #T_ab0dc_row27_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_ab0dc_row9_col0, #T_ab0dc_row24_col4, #T_ab0dc_row28_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ab0dc_row9_col1, #T_ab0dc_row19_col1, #T_ab0dc_row20_col1, #T_ab0dc_row42_col0 {
#   background-color

# %%
df4=df.groupby("Experience").mean()
df4.style.background_gradient(cmap=cm).set_precision(3)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/2842534509.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df4.style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_a9e0a_row0_col0, #T_a9e0a_row2_col8, #T_a9e0a_row8_col2, #T_a9e0a_row10_col5, #T_a9e0a_row11_col7, #T_a9e0a_row12_col1, #T_a9e0a_row16_col4, #T_a9e0a_row16_col6, #T_a9e0a_row17_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a9e0a_row0_col1, #T_a9e0a_row0_col4 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a9e0a_row0_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a9e0a_row0_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a9e0a_row0_col5, #T_a9e0a_row5_col0, #T_a9e0a_row14_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a9e0a_row0_col6, #T_a9e0a_row1_col4, #T_a9e0a_row2_col7, #T_a9e0a_row6_col0, #T_a9e0a_row7_col1, #T_a9e0a_row9_col2, #T_a9e0a_row17_col5, #T_a9e0a_row18_col0, #T_a9e0a_row18_col8, #T_a9e0a_row19_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a9e0a_row0_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a9e0a_row0_col8, #T_a9e0a_row6_col4, #T_a9e0a_row19_col4 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_a9e0a_row1_col0, #T_a9e0a_row13_col1, #T_a9e0a_row15_col8 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T
col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a9e0a_row14_col4 {
#   background-color: #c0282f;
#   color: #

# %%
df5=df.groupby("Married/Single").mean()
df5.style.background_gradient(cmap=cm).set_precision(3)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/728344910.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df5.style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_f9d17_row0_col0, #T_f9d17_row0_col1, #T_f9d17_row0_col4, #T_f9d17_row0_col5, #T_f9d17_row0_col6, #T_f9d17_row0_col8, #T_f9d17_row1_col2, #T_f9d17_row1_col3, #T_f9d17_row1_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f9d17_row0_col2, #T_f9d17_row0_col3, #T_f9d17_row0_col7, #T_f9d17_row1_col0, #T_f9d17_row1_col1, #T_f9d17_row1_col4, #T_f9d17_row1_col5, #T_f9d17_row1_col6, #T_f9d17_row1_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9d17_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >Income</th>
#       <th class="col_heading level0 col2" >Age</th>
#       <th class="col_heading level0 col3" >Experience</th>
#       <th class="col_heading level0 col4" >House_Ownership</th>
#       <th class="col_heading level0 col5" >Car_Ownership</th>
#       <th class="col_heading level0 col6" >CURRENT_JOB_YRS</th>
#       <th class="col_heading level0 col7" >CURRENT_HOUSE_YRS</th>
#       <th class="col_heading level0 col8" >Risk_Flag</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Married/Single</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9d17_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_f9d17_row0_col0" class="data row0 col0" >126028.308</td>
#       <td id="T_f9d17_row0_col1" class="data row0 col1" >4999719.940</td>
#       <td id="T_f9d17_row0_col2" class="data row0 col2" >49.923</td>
#       <td id="T_f9d17_row0_col3" class="data row0 col3" >10.081</td>
#       <td id="T_f9d17_row0_col4" class="data row0 col4" >-0.865</td>
#       <td id="T_f9d17_row0_col5" class="data row0 col5" >0.302</td>
#       <td id="T_f9d17_row0_col6" class="data row0 col6" >6.339</td>
#       <td id="T_f9d17_row0_col7" class="data row0 col7" >11.994</td>
#       <td id="T_f9d17_row0_col8" class="data row0 col8" >0.125</td>
#     </tr>
#     <tr>
#       <th id="T_f9d17_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_f9d17_row1_col0" class="data row1 col0" >125755.937</td>
#       <td id="T_f9d17_row1_col1" class="data row1 col1" >4974221.445</td>
#       <td id="T_f9d17_row1_col2" class="data row1 col2" >50.223</td>
#       <td id="T_f9d17_row1_col3" class="data row1 col3" >10.116</td>
#       <td id="T_f9d17_row1_col4" class="data row1 col4" >-0.905</td>
#       <td id="T_f9d17_row1_col5" class="data row1 col5" >0.300</td>
#       <td id="T_f9d17_row1_col6" class="data row1 col6" >6.288</td>
#       <td id="T_f9d17_row1_col7" class="data row1 col7" >12.029</td>
#       <td id="T_f9d17_row1_col8" class="data row1 col8" >0.102</td>
#     </tr>
#   </tbody>
# </table>

# %%
df6=df.groupby("House_Ownership").mean()
df6.style.background_gradient(cmap=cm).set_precision(4)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/710041970.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df6.style.background_gradient(cmap=cm).set_precision(4)
# <style type="text/css">
# #T_26e7a_row0_col0, #T_26e7a_row0_col3, #T_26e7a_row0_col5, #T_26e7a_row0_col6, #T_26e7a_row1_col1, #T_26e7a_row1_col2, #T_26e7a_row1_col7, #T_26e7a_row2_col4, #T_26e7a_row2_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_26e7a_row0_col1, #T_26e7a_row0_col4, #T_26e7a_row0_col8, #T_26e7a_row1_col0, #T_26e7a_row1_col6, #T_26e7a_row2_col1, #T_26e7a_row2_col2, #T_26e7a_row2_col3, #T_26e7a_row2_col5, #T_26e7a_row2_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_26e7a_row0_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_26e7a_row0_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_26e7a_row1_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_26e7a_row1_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_26e7a_row1_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_26e7a_row1_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_26e7a_row2_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_26e7a_row2_col6 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26e7a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >Income</th>
#       <th class="col_heading level0 col2" >Age</th>
#       <th class="col_heading level0 col3" >Experience</th>
#       <th class="col_heading level0 col4" >Married/Single</th>
#       <th class="col_heading level0 col5" >Car_Ownership</th>
#       <th class="col_heading level0 col6" >CURRENT_JOB_YRS</th>
#       <th class="col_heading level0 col7" >CURRENT_HOUSE_YRS</th>
#       <th class="col_heading level0 col8" >Risk_Flag</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >House_Ownership</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26e7a_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_26e7a_row0_col0" class="data row0 col0" >125942.8550</td>
#       <td id="T_26e7a_row0_col1" class="data row0 col1" >5006940.5024</td>
#       <td id="T_26e7a_row0_col2" class="data row0 col2" >49.8798</td>
#       <td id="T_26e7a_row0_col3" class="data row0 col3" >10.0642</td>
#       <td id="T_26e7a_row0_col4" class="data row0 col4" >0.1044</td>
#       <td id="T_26e7a_row0_col5" class="data row0 col5" >0.3013</td>
#       <td id="T_26e7a_row0_col6" class="data row0 col6" >6.3230</td>
#       <td id="T_26e7a_row0_col7" class="data row0 col7" >11.9934</td>
#       <td id="T_26e7a_row0_col8" class="data row0 col8" >0.1256</td>
#     </tr>
#     <tr>
#       <th id="T_26e7a_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_26e7a_row1_col0" class="data row1 col0" >126722.2287</td>
#       <td id="T_26e7a_row1_col1" class="data row1 col1" >4664033.0707</td>
#       <td id="T_26e7a_row1_col2" class="data row1 col2" >49.8607</td>
#       <td id="T_26e7a_row1_col3" class="data row1 col3" >10.0839</td>
#       <td id="T_26e7a_row1_col4" class="data row1 col4" >0.0828</td>
#       <td id="T_26e7a_row1_col5" class="data row1 col5" >0.3014</td>
#       <td id="T_26e7a_row1_col6" class="data row1 col6" >6.4748</td>
#       <td id="T_26e7a_row1_col7" class="data row1 col7" >11.9649</td>
#       <td id="T_26e7a_row1_col8" class="data row1 col8" >0.0995</td>
#     </tr>
#     <tr>
#       <th id="T_26e7a_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_26e7a_row2_col0" class="data row2 col0" >126633.9460</td>
#       <td id="T_26e7a_row2_col1" class="data row2 col1" >5005999.1843</td>
#       <td id="T_26e7a_row2_col2" class="data row2 col2" >51.3389</td>
#       <td id="T_26e7a_row2_col3" class="data row2 col3" >10.4481</td>
#       <td id="T_26e7a_row2_col4" class="data row2 col4" >0.0715</td>
#       <td id="T_26e7a_row2_col5" class="data row2 col5" >0.3062</td>
#       <td id="T_26e7a_row2_col6" class="data row2 col6" >6.4501</td>
#       <td id="T_26e7a_row2_col7" class="data row2 col7" >12.0944</td>
#       <td id="T_26e7a_row2_col8" class="data row2 col8" >0.0898</td>
#     </tr>
#   </tbody>
# </table>

# %%
df7=df.groupby("Car_Ownership").mean()
df7.style.background_gradient(cmap=cm).set_precision(4)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/778369809.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df7.style.background_gradient(cmap=cm).set_precision(4)
# <style type="text/css">
# #T_b8e62_row0_col0, #T_b8e62_row0_col4, #T_b8e62_row0_col8, #T_b8e62_row1_col1, #T_b8e62_row1_col2, #T_b8e62_row1_col3, #T_b8e62_row1_col5, #T_b8e62_row1_col6, #T_b8e62_row1_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b8e62_row0_col1, #T_b8e62_row0_col2, #T_b8e62_row0_col3, #T_b8e62_row0_col5, #T_b8e62_row0_col6, #T_b8e62_row0_col7, #T_b8e62_row1_col0, #T_b8e62_row1_col4, #T_b8e62_row1_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8e62_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >Income</th>
#       <th class="col_heading level0 col2" >Age</th>
#       <th class="col_heading level0 col3" >Experience</th>
#       <th class="col_heading level0 col4" >Married/Single</th>
#       <th class="col_heading level0 col5" >House_Ownership</th>
#       <th class="col_heading level0 col6" >CURRENT_JOB_YRS</th>
#       <th class="col_heading level0 col7" >CURRENT_HOUSE_YRS</th>
#       <th class="col_heading level0 col8" >Risk_Flag</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Car_Ownership</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8e62_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_b8e62_row0_col0" class="data row0 col0" >126206.6954</td>
#       <td id="T_b8e62_row0_col1" class="data row0 col1" >4989422.3699</td>
#       <td id="T_b8e62_row0_col2" class="data row0 col2" >49.8487</td>
#       <td id="T_b8e62_row0_col3" class="data row0 col3" >10.0548</td>
#       <td id="T_b8e62_row0_col4" class="data row0 col4" >0.1023</td>
#       <td id="T_b8e62_row0_col5" class="data row0 col5" >-0.8696</td>
#       <td id="T_b8e62_row0_col6" class="data row0 col6" >6.3073</td>
#       <td id="T_b8e62_row0_col7" class="data row0 col7" >11.9976</td>
#       <td id="T_b8e62_row0_col8" class="data row0 col8" >0.1282</td>
#     </tr>
#     <tr>
#       <th id="T_b8e62_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_b8e62_row1_col0" class="data row1 col0" >125522.9949</td>
#       <td id="T_b8e62_row1_col1" class="data row1 col1" >5014935.0338</td>
#       <td id="T_b8e62_row1_col2" class="data row1 col2" >50.1980</td>
#       <td id="T_b8e62_row1_col3" class="data row1 col3" >10.1531</td>
#       <td id="T_b8e62_row1_col4" class="data row1 col4" >0.1015</td>
#       <td id="T_b8e62_row1_col5" class="data row1 col5" >-0.8674</td>
#       <td id="T_b8e62_row1_col6" class="data row1 col6" >6.3955</td>
#       <td id="T_b8e62_row1_col7" class="data row1 col7" >11.9983</td>
#       <td id="T_b8e62_row1_col8" class="data row1 col8" >0.1110</td>
#     </tr>
#   </tbody>
# </table>

# %%
df8=df.groupby("Profession").mean()
df8[["Income",'Risk_Flag']].style.background_gradient(cmap=cm).set_precision(3)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/1532280814.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df8[["Income",'Risk_Flag']].style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_98463_row0_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_98463_row0_col1, #T_98463_row28_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_98463_row1_col0, #T_98463_row11_col1, #T_98463_row50_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_98463_row1_col1, #T_98463_row8_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_98463_row2_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_98463_row2_col1, #T_98463_row22_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_98463_row3_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_98463_row3_col1 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_98463_row4_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_98463_row4_col1, #T_98463_row48_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_98463_row5_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_98463_row5_col1, #T_98463_row14_col0, #T_98463_row46_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_98463_row6_col0, #T_98463_row25_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_98463_row6_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_98463_row7_col0, #T_98463_row15_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_98463_row7_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_98463_row8_col0, #T_98463_row17_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_98463_row9_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_98463_row9_col1, #T_98463_row33_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_98463_row10_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_98463_row10_col1, #T_98463_row24_col1, #T_98463_row35_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_98463_row11_col0, #T_98463_row16_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_98463_row12_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_98463_row12_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_98463_row13_col0, #T_98463_row34_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_98463_row13_col1, #T_98463_row48_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_98463_row14_col1, #T_98463_row49_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_98463_row15_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_98463_row16_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_98463_row17_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_98463_row18_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_98463_row18_col1, #T_98463_row50_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_98463_row19_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_98463_row19_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_98463_row20_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_98463_row20_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_98463_row21_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_98463_row21_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_98463_row22_col1, #T_98463_row27_col1, #T_98463_row43_col0, #T_98463_row44_col1, #T_98463_row45_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_98463_row23_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_98463_row23_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_98463_row24_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_98463_row25_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_98463_row26_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_98463_row26_col1, #T_98463_row41_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_98463_row27_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_98463_row28_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_98463_row29_col0, #T_98463_row42_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_98463_row29_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_98463_row30_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_98463_row30_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_98463_row31_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_98463_row31_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_98463_row32_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_98463_row32_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_98463_row33_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_98463_row34_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_98463_row35_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_98463_row36_col0, #T_98463_row38_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_98463_row36_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_98463_row37_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_98463_row37_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_98463_row38_col0, #T_98463_row49_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_98463_row39_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_98463_row39_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_98463_row40_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_98463_row40_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_98463_row41_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_98463_row42_col0, #T_98463_row47_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_98463_row43_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_98463_row44_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_98463_row45_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_98463_row46_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_98463_row47_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# </style>
# <table id="T_98463_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income</th>
#       <th class="col_heading level0 col1" >Risk_Flag</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Profession</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98463_level0_row0" class="row_heading level0 row0" >Air_traffic_controller</th>
#       <td id="T_98463_row0_col0" class="data row0 col0" >4958421.709</td>
#       <td id="T_98463_row0_col1" class="data row0 col1" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row1" class="row_heading level0 row1" >Analyst</th>
#       <td id="T_98463_row1_col0" class="data row1 col0" >4894181.209</td>
#       <td id="T_98463_row1_col1" class="data row1 col1" >0.121</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row2" class="row_heading level0 row2" >Architect</th>
#       <td id="T_98463_row2_col0" class="data row2 col0" >5004078.749</td>
#       <td id="T_98463_row2_col1" class="data row2 col1" >0.131</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row3" class="row_heading level0 row3" >Army_officer</th>
#       <td id="T_98463_row3_col0" class="data row3 col0" >5094472.726</td>
#       <td id="T_98463_row3_col1" class="data row3 col1" >0.152</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row4" class="row_heading level0 row4" >Artist</th>
#       <td id="T_98463_row4_col0" class="data row4 col0" >5164765.182</td>
#       <td id="T_98463_row4_col1" class="data row4 col1" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row5" class="row_heading level0 row5" >Aviator</th>
#       <td id="T_98463_row5_col0" class="data row5 col0" >5074103.520</td>
#       <td id="T_98463_row5_col1" class="data row5 col1" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_98463_level0_row6" class="row_heading level0 row6" >Biomedical_Engineer</th>
#       <td id="T_98463_row6_col0" class="data row6 col0" >4982527.557</td>
#       <td id="T_98463_row6_col1" class="data row6 col1" >0.128</td>
#     </tr>
#     <tr>
#       <th id="T_98463_le

# %%
df9=df.groupby("CITY").mean()
df9.style.background_gradient(cmap=cm).set_precision(3)
# Out:
# C:\Users\Antoine\AppData\Local\Temp/ipykernel_20948/3435945837.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df9.style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_d5147_row0_col0, #T_d5147_row2_col0, #T_d5147_row8_col4, #T_d5147_row15_col9, #T_d5147_row33_col3, #T_d5147_row63_col4, #T_d5147_row81_col9, #T_d5147_row106_col5, #T_d5147_row120_col6, #T_d5147_row124_col0, #T_d5147_row126_col5, #T_d5147_row145_col3, #T_d5147_row148_col6, #T_d5147_row151_col5, #T_d5147_row181_col1, #T_d5147_row191_col0, #T_d5147_row210_col2, #T_d5147_row221_col5, #T_d5147_row225_col7, #T_d5147_row226_col4, #T_d5147_row230_col0, #T_d5147_row237_col3, #T_d5147_row258_col6, #T_d5147_row262_col4, #T_d5147_row294_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d5147_row0_col1, #T_d5147_row49_col0, #T_d5147_row53_col2, #T_d5147_row55_col3, #T_d5147_row62_col2, #T_d5147_row72_col2, #T_d5147_row97_col8, #T_d5147_row106_col3, #T_d5147_row120_col8, #T_d5147_row130_col1, #T_d5147_row131_col3, #T_d5147_row133_col1, #T_d5147_row139_col1, #T_d5147_row142_col1, #T_d5147_row152_col5, #T_d5147_row175_col8, #T_d5147_row235_col2, #T_d5147_row278_col3, #T_d5147_row309_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_d5147_row0_col2, #T_d5147_row32_col7, #T_d5147_row82_col8, #T_d5147_row136_col8, #T_d5147_row160_col2, #T_d5147_row165_col3 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_d5147_row0_col3, #T_d5147_row12_col3, #T_d5147_row35_col8, #T_d5147_row45_col3, #T_d5147_row53_col3, #T_d5147_row61_col8, #T_d5147_row76_col1, #T_d5147_row124_col7, #T_d5147_row132_col0, #T_d5147_row207_col2, #T_d5147_row217_col2, #T_d5147_row226_col1, #T_d5147_row248_col3, #T_d5147_row263_col9, #T_d5147_row291_col7, #T_d5147_row292_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_d5147_row0_col4, #T_d5147_row7_col6, #T_d5147_row24_col6, #T_d5147_row47_col4, #T_d5147_row56_col0, #T_d5147_row95_col9, #T_d5147_row110_col5, #T_d5147_row176_col9, #T_d5147_row179_col4, #T_d5147_row185_col6, #T_d5147_row188_col3, #T_d5147_row189_col1, #T_d5147_row243_col5, #T_d5147_row247_col9, #T_d5147_row269_col0, #T_d5147_row276_col5, #T_d5147_row293_col4, #T_d5147_row308_col4, #T_d5147_row308_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T
py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df10.style.background_gradient(cmap=cm).set_precision(3)
# <style type="text/css">
# #T_fd0b3_row0_col0, #T_fd0b3_row18_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_fd0b3_row0_col1, #T_fd0b3_row2_col9, #T_fd0b3_row26_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fd0b3_row0_col2, #T_fd0b3_row2_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_fd0b3_row0_col3, #T_fd0b3_row0_col6, #T_fd0b3_row14_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_fd0b3_row0_col4, #T_fd0b3_row12_col1, #T_fd0b3_row17_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_fd0b3_row0_col5, #T_fd0b3_row2_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_fd0b3_row0_col7, #T_fd0b3_row16_col9, #T_fd0b3_row25_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_fd0b3_row0_col8, #T_fd0b3_row7_col9, #T_fd0b3_row8_col4, #T_fd0b3_row19_col2, #T_fd0b3_row28_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_fd0b3_row0_col9, #T_fd0b3_row7_col7, #T_fd0b3_row23_col1, #T_fd0b3_row23_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_fd0b3_row1_col0, #T_fd0b3_row3_col1, #T_fd0b3_row8_col0, #T_fd0b3_row9_col5, #T_fd0b3_row9_col7, #T_fd0b3_row12_col3, #T_fd0b3_row15_col4, #T_fd0b3_row16_col7, #T_fd0b3_row16_col8, #T_fd0b3_row21_col2, #T_fd0b3_row21_col9, #T_fd0b3_row26_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fd0b3_row1_col1, #T_fd0b3_row3_col0, #T_fd0b3_row8_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_fd0b3_row1_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_fd0b3_row1_col3, #T_fd0b3_row14_col1, #T_fd0b3_row24_col3, #T_fd0b3_row27_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_fd0b3_row1_col4, #T_fd0b3_row15_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fd0b3_row1_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_fd0b3_row1_col6, #T_fd0b3_row4_col2, #T_fd0b3_row25_col8 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_fd0b3_row1_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_fd0b3_row1_col8, #T_fd0b3_row14_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_fd0b3_row1_col9, #T_fd0b3_row7_col4, #T_fd0b3_row28_col8 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_fd0b3_row2_col0, #T_fd0b3_row18_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_fd0b3_row2_col1, #T_fd0b3_row4_col1, #T_fd0b3_row16_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_fd0b3_row2_col3, #T_fd0b3_row2_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_fd0b3_row2_col4, #T_fd0b3_row3_col6, #T_fd0b3_row11_col1, #T_fd0b3_row23_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_fd0b3_row2_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_fd0b3_row2_col8, #T_fd0b3_row6_col4, #T_fd0b3_row10_col8, #T_fd0b3_row15_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_fd0b3_row3_col2, #T_fd0b3_row22_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_fd0b3_row3_col3, #T_fd0b3_row9_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_fd0b3_row3_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_fd0b3_row3_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_fd0b3_row3_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_fd0b3_row3_col8, #T_fd0b3_row8_col3, #T_fd0b3_row9_col2, #T_fd0b3_row15_col1, #T_fd0b3_row15_col9, #T_fd0b3_row21_col0, #T_fd0b3_row21_col5, #T_fd0b3_row24_col7, #T_fd0b3_row26_col4, #T_fd0b3_row27_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fd0b3_row3_col9, #T_fd0b3_row7_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_fd0b3_row4_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_fd0b3_row4_col3, #T_fd0b3_row5_col7, #T_fd0b3_row27_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_fd0b3_row4_col4, #T_fd0b3_row5_col3, #T_fd0b3_row6_col9, #T_fd0b3_row25_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_fd0b3_row4_col5, #T_fd0b3_row4_col9, #T_fd0b3_row8_col9, #T_fd0b3_row10_col3, #T_fd0b3_row10_col9, #T_fd0b3_row25_col4, #T_fd0b3_row28_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_fd0b3_row4_col6, #T_fd0b3_row12_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_fd0b3_row4_col7, #T_fd0b3_row11_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_fd0b3_row4_col8, #T_fd0b3_row8_col7, #T_fd0b3_row9_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_fd0b3_row5_col0, #T_fd0b3_row28_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_fd0b3_row5_col1, #T_fd0b3_row5_col8, #T_fd0b3_row22_col1, #T_fd0b3_row25_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_fd0b3_row5_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_fd0b3_row5_col4, #T_fd0b3_row5_col6, #T_fd0b3_row7_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_fd0b3_row5_col5, #T_fd0b3_row28_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_fd0b3_row5_col9, #T_fd0b3_row10_col7, #T_fd0b3_row26_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_fd0b3_row6_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_fd0b3_row6_col1, #T_fd0b3_row7_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_fd0b3_row6_col2, #T_fd0b3_row6_col6, #T_fd0b3_row14_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_fd0b3_row6_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_fd0b3_row6_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_fd0b3_row6_col7, #T_fd0b3_row6_col8 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_fd0b3_row7_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_fd0b3_row7_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_fd0b3_row7_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_fd0b3_row7_col8, #T_fd0b3_row11_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_fd0b3_row8_col1, #T_fd0b3_row15_col0, #T_fd0b3_row27_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_fd0b3_row8_col2, #T_fd0b3_row18_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_fd0b3_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_fd0b3_row8_col8 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_fd0b3_row9_col0, #T_fd0b3_row21_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_fd0b3_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_fd0b3_row9_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_fd0b3_row9_col4, #T_fd0b3_row21_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_fd0b3_row9_col8, #T_fd0b3_row13_col5, #T_fd0b3_row22_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_fd0b3_row10_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_fd0b3_row10_col1, #T_fd0b3_row11_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_fd0b3_row10_col2, #T_fd0b3_row19_col8, #T_fd0b3_row24_col9 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_fd0b3_row10_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_fd0b3_row10_col5 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_fd0b3_row10_col6, #T_fd0b3_row17_col9, #T_fd0b3_row28_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_fd0b3_row11_col0, #T_fd0b3_row27_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_fd0b3_row11_col3, #T_fd0b3_row18_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_fd0b3_row11_col4, #T_fd0b3_row14_col3, #T_fd0b3_row23_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_fd0b3_row11_col5, #T_fd0b3_row20_col3, #T_fd0b3_row20_col9, #T_fd0b3_row28_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_fd0b3_row11_col8, #T_fd0b3_row25_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_fd0b3_row11_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fd0b3_row12_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_fd0b3_row12_col2 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_fd0b3_row12_col4, #T_fd0b3_row14_col4, #T_fd0b3_row21_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_fd0b3_row12_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_fd0b3_row12_col7 {

# %%
df["Age"].plot.box()
# Out:
# <AxesSubplot:>

# %%
print(df.Income.quantile(0.1))
np.array(df.Income.quantile(np.linspace(.1, 1, 9, 0)))
# Out:
# 1028915.0
# array([1028915. , 2010564. , 2974371. , 3983449. , 5000694.5, 5997509. ,
#        6975092. , 7957694. , 8998014. ])

# %%
# New variables will be created for the deciles of the relevant variables
df.Income.rank(pct = True)
# Out:
# 0         0.127139
# 1         0.760984
# 2         0.401139
# 3         0.626071
# 4         0.575962
#             ...
# 251995    0.817413
# 251996    0.287238
# 251997    0.454591
# 251998    0.651188
# 251999    0.906452
# Name: Income, Length: 252000, dtype: float64
